# %%
H,W,N = map(int, input().split())
A = list(set(map(int, input().split())) for _ in range(H))
B = set(int(input()) for _ in range(N))
answer = 0
for a in A:
    answer = max(len(a & B),answer)
print(answer)
